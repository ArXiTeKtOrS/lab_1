# %% [markdown]
# <a href="https://colab.research.google.com/github/ArXiTeKtOrS/lab_1/blob/main/5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'

# %%
file_path = "/content/drive/MyDrive/my_text_file.txt"
with open(file_path, "w") as f:
    f.write("Это тестовый файл, сохраненый в Google Drive.\n")
    f.write("Вторая строка текста.")

print("Файл успешно сохранен в Google Drive.")
# Out:
# Файл успешно сохранен в Google Drive.

# %%
with open (file_path, "r") as f:
    content = f.read()
    print("Содержимое файла:\n", content)
# Out:
# Содержимое файла:
#  Это тестовый файл, сохраненый в Google Drive.
# Вторая строка текста.

# %%
students = [
    ["Ромащенко Д.П.", 20, "ИВТ-б-о-24-1"],
    ["Аверин М.С.", 19, "ИВТ-б-о-24-1"],
    ["Грабарь А.П.", 19, "ИВТ-б-о-24-1"]
]

csv_path = "/content/drive/MyDrive/students.csv"
with open(csv_path, "w") as f:
    for student in students:
        f.write(",".join(map(str, student)) + "\n")

print("Файл students.csv успешно сохранен в Google Drive")
# Out:
# Файл students.csv успешно сохранен в Google Drive

# %%
# !ls /content/drive/MyDrive/*.txt
# Out:
# /content/drive/MyDrive/my_text_file.txt
