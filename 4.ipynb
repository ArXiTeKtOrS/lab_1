# %% [markdown]
# <a href="https://colab.research.google.com/github/ArXiTeKtOrS/lab_1/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !mkdir test_folder

# %%
# !ls
# Out:
# sample_data  test_folder

# %%
with open("example.txt", "w") as f:
  f.write("Text\n")

# %%
# !ls
# Out:
# example.txt  sample_data  test_folder

# %%
# !mv example.txt test_folder/

# %%
# !ls test_folder/
# Out:
# example.txt

# %%
# !rm test_folder/example.txt

# %%
# !ls test_folder/

# %%
# !clear
